# %%
import pandas as pd

# %%
df=pd.read_csv("youtube-top-100-songs-2025 (4).csv")

# %%
df.head()
# Out:
#                                                title  \
# 0   ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2  Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3  Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4            Reneé Rapp - Mad (Official Music Video)
#
#                                            fulltitle  \
# 0   ROSÉ & Bruno Mars - APT. (Official Music Video)
# 1  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# 2  Reneé Rapp - Leave Me Alone (Official Music Vi...
# 3  Billie Eilish - BIRDS OF A FEATHER (Official M...
# 4            Reneé Rapp - Mad (Official Music Video)
#
#                                          description  view_count categories  \
# 0  ROSÉ & Bruno Mars - APT.\nDownload/stream: ht...  2009014557      Music
# 1  MAYHEM OUT NOW\nhttp://ladygaga.com \n \nListe...  1324833300      Music
# 2  Listen to “BITE ME”, the new album from Reneé ...     2536628      Music
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   100 non-null    object
#  1   fulltitle               100 non-null    object
#  2   description             100 non-null    object
#  3   view_count              100 non-null    int64
#  4   categories              100 non-null    object
#  5   tags                    85 non-null     object
#  6   duration                100 non-null    int64
#  7   duration_string         100 non-null    object
#  8   live_status             100 non-null    bool
#  9   thumbnail               100 non-null    object
#  10  channel                 100 non-null    object
#  11  channel_url             100 non-null    object
#  12  channel_follower_count  100 non-null    int64
# dtypes: bool(1), int64(3), object(9)
# memory usage: 9.6+ KB

# %% [markdown]
# # Classification algoritmlar
#
#
#
# | № | Algorithm Name | Import Code |
# |---|----------------|--------------|
# | 1 | Logistic Regression | `from sklearn.linear_model import LogisticRegression` |
# | 2 | Decision Tree Classifier | `from sklearn.tree import DecisionTreeClassifier` |
# | 3 | Random Forest Classifier | `from sklearn.ensemble import RandomForestClassifier` |
# | 4 | K-Nearest Neighbors (KNN) Classifier | `from sklearn.neighbors import KNeighborsClassifier` |
# | 5 | Support Vector Classifier (SVC) | `from sklearn.svm import SVC` |
# | 6 | Gradient Boosting Classifier | `from sklearn.ensemble import GradientBoostingClassifier` |
# | 7 | AdaBoost Classifier | `from sklearn.ensemble import AdaBoostClassifier` |
# | 8 | XGBoost Classifier | `from xgboost import XGBClassifier` |
# | 9 | CatBoost Classifier | `from catboost import CatBoostClassifier` |
# | 10 | LightGBM Classifier | `from lightgbm import LGBMClassifier` |
# | 11 | Naive Bayes (GaussianNB) | `from sklearn.naive_bayes import GaussianNB` |
# | 12 | Multinomial Naive Bayes | `from sklearn.naive_bayes import MultinomialNB` |
# | 13 | Bernoulli Naive Bayes | `from sklearn.naive_bayes import BernoulliNB` |
# | 14 | Complement Naive Bayes | `from sklearn.naive_bayes import ComplementNB` |
# | 15 | Extra Trees Classifier | `from sklearn.ensemble import ExtraTreesClassifier` |
# | 16 | Passive Aggressive Classifier | `from sklearn.linear_model import PassiveAggressiveClassifier` |
# | 17 | Perceptron | `from sklearn.linear_model import Perceptron` |
# | 18 | Stochastic Gradient Descent (SGD) Classifier | `from sklearn.linear_model import SGDClassifier` |
# | 19 | Bagging Classifier | `from sklearn.ensemble import BaggingClassifier` |
# | 20 | Voting Classifier | `from sklearn.ensemble import VotingClassifier` |

# %% [markdown]
# # Regression algoritmlar
#
#
# | № | Algorithm Name | Import Code |
# |---|----------------|--------------|
# | 1 | Linear Regression | `from sklearn.linear_model import LinearRegression` |
# | 2 | Ridge Regression | `from sklearn.linear_model import Ridge` |
# | 3 | Lasso Regression | `from sklearn.linear_model import Lasso` |
# | 4 | ElasticNet Regression | `from sklearn.linear_model import ElasticNet` |
# | 5 | Decision Tree Regressor | `from sklearn.tree import DecisionTreeRegressor` |
# | 6 | Random Forest Regressor | `from sklearn.ensemble import RandomForestRegressor` |
# | 7 | K-Nearest Neighbors (KNN) Regressor | `from sklearn.neighbors import KNeighborsRegressor` |
# | 8 | Support Vector Regressor (SVR) | `from sklearn.svm import SVR` |
# | 9 | Gradient Boosting Regressor | `from sklearn.ensemble import GradientBoostingRegressor` |
# | 10 | AdaBoost Regressor | `from sklearn.ensemble import AdaBoostRegressor` |
# | 11 | XGBoost Regressor | `from xgboost import XGBRegressor` |
# | 12 | CatBoost Regressor | `from catboost import CatBoostRegressor` |
# | 13 | LightGBM Regressor | `from lightgbm import LGBMRegressor` |
# | 14 | Extra Trees Regressor | `from sklearn.ensemble import ExtraTreesRegressor` |
# | 15 | SGD Regressor | `from sklearn.linear_model import SGDRegressor` |
# | 16 | Bayesian Ridge Regressor | `from sklearn.linear_model import BayesianRidge` |
# | 17 | Huber Regressor | `from sklearn.linear_model import HuberRegressor` |
# | 18 | TheilSen Regressor | `from sklearn.linear_model import TheilSenRegressor` |
# | 19 | RANSAC Regressor | `from sklearn.linear_model import RANSACRegressor` |
# | 20 | Passive Aggressive Regressor | `from sklearn.linear_model import PassiveAggressiveRegressor` |
